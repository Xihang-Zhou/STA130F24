# %% [markdown]
# Q1</br>
# Explain succinctly in your own words </br>
# 1. the difference between Simple Linear Regression and Multiple Linear Regression; and the benefit the latter provides over the former</br>Simple Linear Regression only has one independent variable, i.e. only x. Whereas Multiple Linear Regression takes multiple independent variables, i.e. a vector X containing any number of entries. The latter allows us to analyse models containing more dimentions instead of only one dimention, also, the vector space can be polynomial which allows us to fit in any smooth curve.
# 2. Continuous Variable predicts the outcome variable Y across the range of values given. Which means it shows the trend of change of Y over x. Whereas Indicator Variable shows the shift of line between categories.
# 3. from $$outcome=β_0+β_1(\text{predictorA})$$ to $$outcome=β_0+β_1(\text{predictorA})+β_2⋅1(\text{predictorB})$$ Adding the indicator variable lets the model split into two lines for groups with only adjustment in intercept, effectively modeling group-specific baseline shifts while maintaining the same trend (slope) for the continuous variable across groups.
# 4. $$outcome=β_0+β_1(\text{predictorA})+β_2⋅1(\text{predictorB})+β_3⋅(\text{predictorA})⋅1(\text{predictorb})$$This model allows each group to have its own intercept and slope, enabling different gradient in the outcome for each group based on predictorA. It’s particularly useful when we believe there is a relationship between the continuous predictor and outcome varies by group.
# 5. the graph should be different horizontal lines at differnt c for y=c. We can pick any one group as the baseline to compare with other groups. The reason of using k-1 indicator is to maintain interpretibility of the graph by avoid two group have a same x but different y, causing that the mapping cannot be function.
#
#
#
# Chatbot: https://chatgpt.com/share/67312a26-dc80-8002-8d5e-95a8892e142c
#
# Here’s a summary of our exchanges for your homework submission:
#
# Introduction to Simple and Multiple Linear Regression: We discussed the basics of Simple Linear Regression (SLR) and Multiple Linear Regression (MLR), including their equations. We highlighted that SLR models one predictor, while MLR accommodates multiple predictors, which enables it to capture more complex relationships in data. Adding additional predictors, like an indicator variable, enhances the model’s explanatory power by allowing it to account for differences across groups or categories.
#
# Continuous vs. Indicator Variables in SLR: We examined how using a continuous variable (e.g., age) in SLR models a linear relationship across all values. An indicator (binary) variable, however, allows us to model the effect of a categorical variable by shifting the baseline intercept. Equations were provided for both cases:
#
# Continuous SLR:
# outcome
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# ⋅
# continuous predictor
# outcome=β
# 0
# ​
#  +β
# 1
# ​
#  ⋅continuous predictor
# Indicator SLR:
# outcome
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# ⋅
# 1
# (
# category
# )
# outcome=β
# 0
# ​
#  +β
# 1
# ​
#  ⋅1(category)
# Transition to MLR with a Continuous and an Indicator Variable: When both a continuous and an indicator variable are included in MLR, it allows the model to show different baselines for each group but keeps the slope constant across groups. We illustrated this with an income example where age was a continuous variable and group membership was an indicator. This produced a model with different intercepts for each group, but with parallel slopes.
#
# Adding an Interaction Term: We explored how an interaction term between a continuous and an indicator variable changes the model, allowing each group to have its own unique slope, which represents group-specific effects in how the continuous predictor influences the outcome. The resulting equation was:
#
# outcome
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# ⋅
# (
# predictorA
# )
# +
# 𝛽
# 2
# ⋅
# 1
# (
# predictorB
# )
# +
# 𝛽
# 3
# ⋅
# (
# predictorA
# )
# ⋅
# 1
# (
# predictorB
# )
# outcome=β
# 0
# ​
#  +β
# 1
# ​
#  ⋅(predictorA)+β
# 2
# ​
#  ⋅1(predictorB)+β
# 3
# ​
#  ⋅(predictorA)⋅1(predictorB)
# This form enabled the model to capture distinct slopes for each group.
#
# Using Indicator Variables for Categorical Data with Multiple Categories: Finally, we discussed how to model categorical variables with more than two levels by introducing multiple indicator variables, explaining why we use “number of categories minus one” indicators to avoid multicollinearity and how this choice facilitates model interpretability. An example with three job sectors (Technology, Healthcare, and Education) illustrated how one category (e.g., Technology) is treated as the baseline, while the other categories' effects are compared to this baseline. The concept of a baseline group allows for straightforward interpretation, as coefficients of the indicators represent differences relative to the baseline category.
#
# Throughout these exchanges, we covered multiple equations, explanations, and a few visual examples to aid understanding. The final summary offered a translated explanation in Chinese for clarity.

# %% [markdown]
# Q2</br>
# outcome: sales</br>
# Predictor: TV Advertising Budget and Online Advertising Budget</br>
# Linear Models without Interaction: $$\text{Sales}=\beta_0+\beta_1 \times \text{TV Budget}+\beta_2 \times \text{Online Budget}+\epsilon$$
# As the question, effectiveness of one may be higher if the other is higher, let's add a term β3×TV_Budget×Online_Budget. Hence linear Models with Interaction:$$\text{Sales}=\beta_0+\beta_1 \times \text{TV Budget}+\beta_2 \times \text{Online Budget}+\times \beta_3 \text{TV Budget} \times\text{Online Budget}+\epsilon$$
# first one assume independentness of independent variables while the second do not assume that, multiple LR will be used to analyse.</br>
# the updated version(binary) is just take a value x to be the discriminant so that I(budget >= x) is considered.

# %% [markdown]
# Q3 below

# %%
import pandas as pd
import statsmodels.formula.api as smf

url = "https://raw.githubusercontent.com/pointOfive/stat130chat130/refs/heads/main/CP/CSCS_data_anon.csv"
data = pd.read_csv("CSCS_data_anon.csv")
df['ELIGIBLE_consent'] = (df['ELIGIBLE_consent'] == 'Yes').astype(int)

# Logistic regression formula specifying main effects and possible interactions
logistic_formula = 'ELIGIBLE_consent ~ SURVEY_response_type  + DEMO_disability_none + SURVEY_recontact'

# Fit the logistic regression model
log_reg_fit = smf.logit(logistic_formula, data=df).fit()

# Output the summary of the logistic regression model
print(log_reg_fit.summary())
# Out:
# /tmp/ipykernel_101/259611983.py:5: DtypeWarning: Columns (408,1001,1002,1006,1007,1008,1080,1113,1115,1116,1117,1118,1119,1120,1121,1124,1125,1126,1127,1128,1213,1214,1215,1216,1217,1218,1342,1343,1344,1345,1346,1347,1348,1349,1390,1391,1393,1463,1549,1552,1555,1558,1561) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("CSCS_data_anon.csv")
# ...
#          Current function value: 0.000000
#          Iterations: 35
#                            Logit Regression Results
# ...
# Dep. Variable:       ELIGIBLE_consent   No. Observations:                 4250
# Model:                          Logit   Df Residuals:                     4243
# Method:                           MLE   Df Model:                            6
# Date:                Mon, 11 Nov 2024   Pseudo R-squ.:                     inf
# Time:                        23:02:08   Log-Likelihood:            -2.4759e-08
# ...

# %% [markdown]
# I have no idea what happend above so just use the example code

# %%
import pandas as pd
import statsmodels.formula.api as smf

url = "https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv"
pokeaman = pd.read_csv(url).fillna('None')

pokeaman['str8fyre'] = (pokeaman['Type 1']=='Fire').astype(int)
linear_model_specification_formula = \
'str8fyre ~ Attack*Legendary + Defense*I(Q("Type 2")=="None") + C(Generation)'
log_reg_fit = smf.logit(linear_model_specification_formula, data=pokeaman).fit()
log_reg_fit.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.228109
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:               str8fyre   No. Observations:                  800
# Model:                          Logit   Df Residuals:                      788
# Method:                           MLE   Df Model:                           11
# Date:                Mon, 11 Nov 2024   Pseudo R-squ.:                 0.05156
# Time:                        23:12:57   Log-Likelihood:                -182.49
# converged:                       True   LL-Null:                       -192.41
# Covariance Type:            nonrobust   LLR p-value:                   0.04757
# ...
#                                                coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %% [markdown]
# intermediate evidence to say that when the Legendary variable is True, the log-odds of str8fyre being 1 (the outcome event) increases by about 4.35, compared to when it's False because statistically significant at the 0.05 level (p = 0.046) other prediction so on.

# %%
log_reg_fit.params
# Out:
# Intercept                                  -3.264384
# Legendary[T.True]                           4.347822
# I(Q("Type 2") == "None")[T.True]            1.543208
# C(Generation)[T.2]                         -0.057405
# C(Generation)[T.3]                         -0.647952
# C(Generation)[T.4]                         -0.825459
# C(Generation)[T.5]                         -0.537510
# C(Generation)[T.6]                          0.321284
# Attack                                      0.017157
# Attack:Legendary[T.True]                   -0.036470
# Defense                                    -0.009838
# Defense:I(Q("Type 2") == "None")[T.True]   -0.019692
# dtype: float64

# %%
import plotly.graph_objects as go
import numpy as np
intercept = log_reg_fit.params['Intercept']
coef_attack = log_reg_fit.params['Attack']
coef_legendary = log_reg_fit.params['Legendary[T.True]']
coef_interaction = log_reg_fit.params['Attack:Legendary[T.True]']
# Simulate data for plotting
attack_vals = np.linspace(min(pokeaman['Attack']), max(pokeaman['Attack']), 100)
legendary_vals = [0, 1]  # Binary variable: False (0) and True (1)

# Additive model predictions (no interaction term)
additive_preds = intercept + coef_attack * attack_vals + coef_legendary * legendary_vals[1] + noise

# Interaction model predictions (with interaction term)
interaction_preds = intercept + coef_attack * attack_vals + coef_legendary * legendary_vals[1] + coef_interaction * attack_vals * legendary_vals[1]

# Create figure
fig = go.Figure()

# Plot additive model
fig.add_trace(go.Scatter(x=attack_vals, y=additive_preds, mode='lines', name="Additive Model"))

# Plot interaction model
fig.add_trace(go.Scatter(x=attack_vals, y=interaction_preds, mode='lines', name="Interaction Model"))

# Layout
fig.update_layout(
    title="Logistic Regression: Additive vs Interaction Model",
    xaxis_title="Attack",
    yaxis_title="Predicted Probability",
    legend_title="Model Type"
)

fig.show(renderer='png')

# %%
import plotly.graph_objects as go
import numpy as np
import pandas as pd

# Extract coefficients from the fitted model
intercept = log_reg_fit.params['Intercept']
coef_attack = log_reg_fit.params['Attack']
coef_legendary = log_reg_fit.params['Legendary[T.True]']
coef_interaction = log_reg_fit.params['Attack:Legendary[T.True]']

# Simulate data for plotting
# Generate a range of attack values (e.g., 0 to 200, based on data range)
attack_vals = np.linspace(min(pokeaman['Attack']), max(pokeaman['Attack']), 100)

# Simulate Legendary values (0 for False, 1 for True)
legendary_vals = [0, 1]

# Random noise (to simulate variance in the data)
np.random.seed(42)
noise = np.random.normal(0, 0.1, size=attack_vals.shape[0])

# Additive model predictions (without interaction)
additive_preds = intercept + coef_attack * attack_vals + coef_legendary * legendary_vals[1] + noise

# Interaction model predictions (with interaction term)
interaction_preds = intercept + coef_attack * attack_vals + coef_legendary * legendary_vals[1] + coef_interaction * attack_vals * legendary_vals[1] + noise

# Create figure
fig = go.Figure()

# Additive model with noise
fig.add_trace(go.Scatter(x=attack_vals, y=additive_preds, mode='markers', name="Additive Model (with noise)", marker=dict(color='blue', opacity=0.6)))

# Interaction model with noise
fig.add_trace(go.Scatter(x=attack_vals, y=interaction_preds, mode='markers', name="Interaction Model (with noise)", marker=dict(color='red', opacity=0.6)))

# Layout
fig.update_layout(
    title="Logistic Regression: Additive vs Interaction Model with Noise",
    xaxis_title="Attack",
    yaxis_title="Predicted Probability (with noise)",
    legend_title="Model Type"
)

fig.show(renderer='png')

# %% [raw]
# GPT: https://chatgpt.com/share/673290cc-0680-8002-b447-aaac96205a73
#
# Summary of Interactions:
# Initial Request for Logistic Regression Analysis:
#
# You requested assistance with a logistic regression model where the outcome variable is binary, and the predictor variables include continuous, binary, and categorical variables.
# You provided a summary table from your logistic regression output using smf.logit() in Statsmodels. We discussed how to interpret the model coefficients, p-values, and the interaction term in the context of a logistic regression model.
# The provided model included variables like Attack, Legendary, Generation, and Defense, as well as interactions like Attack:Legendary[T.True].
# Interpretation of Logistic Regression Output:
#
# We went over the logistic regression output, explaining the key coefficients, including the intercept, main effects (e.g., Attack, Legendary), and interaction terms.
# We interpreted the statistical significance of each variable and discussed how you might use the coefficients to make predictions about the outcome variable, str8fyre.
# We also noted how the p-value of the Attack:Legendary interaction term is marginally significant, suggesting it might influence the outcome.
# Request for Simplification:
#
# You asked to treat the logistic regression as if it were a multivariate linear regression for ease of interpretation, ignoring the complexity of log-odds.
# You requested that I simulate random noise in the data and generate plots with both additive and interaction model specifications for the predicted probabilities.
# Visualization with Plotly:
#
# I provided you with code using Plotly to visualize the model predictions for both the additive and interaction models.
# The code involved simulating Attack values and adding random noise to generate more realistic data for the plots.
# The final visualization shows the predicted probabilities for both models, with noise added to simulate variability in the data, even though the logistic regression model technically deals with binary outcomes.
# Final Adjustments:
#
# After encountering a NameError related to undefined variables (intercept, coef_attack, etc.), I clarified how to extract the fitted coefficients from the log_reg_fit object and correctly implemented the predictions and noise generation.
# Summary Request:
#
# You asked for a summary of our interactions to submit as part of a homework assignment.

# %% [markdown]
# Q4.Explain the apparent contradiction between the factual statements regarding the fit below that "the model only explains 17.6% of the variability in the data" while at the same time "many of the coefficients are larger than 10 while having strong or very strong evidence against the null hypothesis of 'no effect'"

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv"
# fail https://github.com/KeithGalli/pandas/blob/master/pokemon_data.csv
pokeaman = pd.read_csv(url) 
pokeaman
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
import statsmodels.formula.api as smf

model1_spec = smf.ols(formula='HP ~ Q("Sp. Def") + C(Generation)', data=pokeaman)
model2_spec = smf.ols(formula='HP ~ Q("Sp. Def") + C(Generation) + Q("Sp. Def"):C(Generation)', data=pokeaman)
model2_spec = smf.ols(formula='HP ~ Q("Sp. Def") * C(Generation)', data=pokeaman)

model2_fit = model2_spec.fit()
model2_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.176
# Model:                            OLS   Adj. R-squared:                  0.164
# Method:                 Least Squares   F-statistic:                     15.27
# Date:                Wed, 13 Nov 2024   Prob (F-statistic):           3.50e-27
# Time:                        20:28:19   Log-Likelihood:                -3649.4
# No. Observations:                 800   AIC:                             7323.
# Df Residuals:                     788   BIC:                             7379.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Q4 answer: There may be uncaptured independent variables so that there is a hidden variable controlling the outcome, which lead to less R-square. Also, the original population distribution may has a high standard deviation which leads to less R-square, Although the independent variables are matched decently, but they are not all about the true equation. Also, by the Notes given [2] The condition number is large, 1.4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Q5: Discuss the following (five cells of) code and results with a ChatBot and based on the understanding you arrive at in this conversation explain what the following (five cells of) are illustrating

# %%
import numpy as np
from sklearn.model_selection import train_test_split

fifty_fifty_split_size = int(pokeaman.shape[0]*0.5)

# Replace "NaN" (in the "Type 2" column with "None")
pokeaman.fillna('None', inplace=True)

np.random.seed(130)
pokeaman_train,pokeaman_test = \
  train_test_split(pokeaman, train_size=fifty_fifty_split_size)
pokeaman_train
# Out:
#        #                     Name   Type 1   Type 2  HP  Attack  Defense  \
# 370  338                  Solrock     Rock  Psychic  70      95       85
# 6      6                Charizard     Fire   Flying  78      84       78
# 242  224                Octillery    Water     None  75     105       75
# 661  600                    Klang    Steel     None  60      80       95
# 288  265                  Wurmple      Bug     None  45      45       35
# ..   ...                      ...      ...      ...  ..     ...      ...
# 522  471                  Glaceon      Ice     None  65      60      110
# 243  225                 Delibird      Ice   Flying  45      55       45
# 797  720      HoopaHoopa Confined  Psychic    Ghost  80     110       60
# 117  109                  Koffing   Poison     None  40      65       95
# 409  373  SalamenceMega Salamence   Dragon   Flying  95     145      130
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# It splits dataset to train set and test set (50% and 50%) to test the effect of model based on train set

# %%
model_spec3 = smf.ols(formula='HP ~ Attack + Defense', 
                      data=pokeaman_train)
model3_fit = model_spec3.fit()
model3_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.143
# Method:                 Least Squares   F-statistic:                     34.40
# Date:                Wed, 13 Nov 2024   Prob (F-statistic):           1.66e-14
# Time:                        20:28:23   Log-Likelihood:                -1832.6
# No. Observations:                 400   AIC:                             3671.
# Df Residuals:                     397   BIC:                             3683.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     42.5882      3.580     11.897      0.000      35.551      49.626
# ...

# %% [markdown]
# It build a model based on train set using ols, HP is the dependent variable, ATK and DEF are the independent variables.
# Then conclude a summary from the model

# %%
yhat_model3 = model3_fit.predict(pokeaman_test)
y = pokeaman_test.HP
print("'In sample' R-squared:    ", model3_fit.rsquared)
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model3)[0,1]**2)
# Out:
# 'In sample' R-squared:     0.14771558304519894
# 'Out of sample' R-squared: 0.21208501873920738

# %% [markdown]
# It calculate R-squared of the model with the test set and print it with R-squared from the train test.

# %%
model4_linear_form = 'HP ~ Attack * Defense * Speed * Legendary'
model4_linear_form += ' * Q("Sp. Def") * Q("Sp. Atk")'
# DO NOT try adding '* C(Generation) * C(Q("Type 1")) * C(Q("Type 2"))'
# That's 6*18*19 = 6*18*19 possible interaction combinations...
# ...a huge number that will blow up your computer

model4_spec = smf.ols(formula=model4_linear_form, data=pokeaman_train)
model4_fit = model4_spec.fit()
model4_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.369
# Method:                 Least Squares   F-statistic:                     4.764
# Date:                Wed, 13 Nov 2024   Prob (F-statistic):           4.23e-21
# Time:                        20:28:28   Log-Likelihood:                -1738.6
# No. Observations:                 400   AIC:                             3603.
# Df Residuals:                     337   BIC:                             3855.
# Df Model:                          62
# Covariance Type:            nonrobust
# ...
#                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# Similarly, another model is trained based on train set. However, this new model takes more independent variables and interaction into account. Then summary is concluded.

# %%
yhat_model4 = model4_fit.predict(pokeaman_test)
y = pokeaman_test.HP
print("'In sample' R-squared:    ", model4_fit.rsquared)
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model4)[0,1]**2)
# Out:
# 'In sample' R-squared:     0.46709442115833855
# 'Out of sample' R-squared: 0.002485342598992873

# %% [markdown]
# It calculate R-squared of the model with the test set and print it with R-squared from the train test.

# %% [markdown]
# Here no chatbot used in Q5 and Q6 since their answer did not make sense.

# %% [markdown]
# Q6</br>
# Note that HP ~ Attack * Defense * Speed * Legendary * Q("Sp. Def") * Q("Sp. Atk") uses 6 independent variables multipling together.
#
#
# Hence, the matrix produced takes all the possible combination of variables which are 6C1+6C2+...+6C6 columns and number of rows is same as train_set. This leads to error since interactions of variables are not linearly independent, these predictors can be very related, minor change in data may lead to totally different result, causing over-fitting. kind of like we want a quadratic but a P_6(x) is given, it do matches better with test data but completely failed in acutally distribution. So it cannot be generalized to the dataset other than test set.

# %% [markdown]
# Q7</br>
# From model3 to 4</br>
# Model complexity increased a lot and a lot interaction is considered
# then to 5</br>
# Model Complexity is reduced since no interaction is considered, although there are two more predictors(catagorical variables), but there are less possible combination so design matrix is smaller.
# then to 6</br>
# Variable Selection Based on Significance, i.e., variables that are not statistically significant are filtered out, also, only certain indicator values are included so that model is simpler.</br>
# Finally 7.</br>
# Interaction is included again, but only with some of the variables and still filter variables based on significance and meaningfulness to HP, so that design matrix are not too complex.

# %%
# Q8
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import plotly.express as px
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split

# Ensure categorical variables have consistent categories
pokeaman["Type 1"] = pd.Categorical(pokeaman["Type 1"], 
                                         categories=pokeaman["Type 1"].unique())
pokeaman["Type 2"] = pd.Categorical(pokeaman["Type 2"], 
                                         categories=pokeaman["Type 2"].unique())
pokeaman["Generation"] = pd.Categorical(pokeaman["Generation"])

# Define the number of repetitions
reps = 100

# Define model specifications for models 3, 4, 5, 6, and 7
model_specs = {
    "Model 3": 'HP ~ Attack + Defense + Speed',
    "Model 4": 'HP ~ Attack * Defense * Speed * Legendary * Q("Sp. Def") * Q("Sp. Atk")',
    "Model 5": 'HP ~ Attack + Defense + Speed + Legendary + Q("Sp. Def") + Q("Sp. Atk") + C(Generation) + C(Q("Type 1")) + C(Q("Type 2"))',
    "Model 6": 'HP ~ Attack + Speed + Q("Sp. Def") + Q("Sp. Atk") + I(Q("Type 1")=="Normal") + I(Q("Type 1")=="Water") + I(Generation==2) + I(Generation==5)',
    "Model 7": 'HP ~ Attack * Speed * Q("Sp. Def") * Q("Sp. Atk") + I(Q("Type 1")=="Normal") + I(Q("Type 1")=="Water") + I(Generation==2) + I(Generation==5)'
}

# Initialize a DataFrame to store results
results = pd.DataFrame(columns=["Model", "In Sample R-squared", "Out of Sample R-squared"])

# Loop over each model specification
for model_name, linear_form in model_specs.items():
    in_sample_Rsquared = np.zeros(reps)
    out_of_sample_Rsquared = np.zeros(reps)
    
    # Perform 100 repetitions with 50-50 train-test splits
    for i in range(reps):
        # 50-50 train-test split
        pokeaman_train, pokeaman_test = train_test_split(pokeaman, train_size=0.5)
        
        # Ensure consistent categories in train and test sets
        pokeaman_train["Type 1"] = pokeaman_train["Type 1"].cat.set_categories(pokeaman["Type 1"].cat.categories)
        pokeaman_train["Type 2"] = pokeaman_train["Type 2"].cat.set_categories(pokeaman["Type 2"].cat.categories)
        pokeaman_test["Type 1"] = pokeaman_test["Type 1"].cat.set_categories(pokeaman["Type 1"].cat.categories)
        pokeaman_test["Type 2"] = pokeaman_test["Type 2"].cat.set_categories(pokeaman["Type 2"].cat.categories)

        # Fit the model
        model_fit = smf.ols(formula=linear_form, data=pokeaman_train).fit()
        
        # Collect in-sample R-squared
        in_sample_Rsquared[i] = model_fit.rsquared
        
        # Collect out-of-sample R-squared
        y_test = pokeaman_test.HP
        y_pred_test = model_fit.predict(pokeaman_test)
        out_of_sample_Rsquared[i] = np.corrcoef(y_test, y_pred_test)[0, 1] ** 2
    
    # Append results to DataFrame
    model_results = pd.DataFrame({
        "Model": model_name,
        "In Sample R-squared": in_sample_Rsquared,
        "Out of Sample R-squared": out_of_sample_Rsquared
    })
    results = pd.concat([results, model_results], ignore_index=True)

# Visualize the results
fig = px.scatter(results, x="In Sample R-squared", y="Out of Sample R-squared",
                 color="Model", title="In Sample vs Out of Sample R-squared across Different Models")

# Add a y=x line for reference
fig.add_trace(go.Scatter(x=[0, 1], y=[0, 1], name="y=x", line=dict(dash="dash")))

# Show the plot
fig.show(renderer='png')
# Out:
# /tmp/ipykernel_85/46008480.py:64: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.

# %% [markdown]
# This graph shows generalizability and correctness of the model, the higher the better result. If x is far larger than y, then over fitting occurs, model 6 seems to show the best result.

# %% [markdown]
# Q9

# %%
model7_gen1_predict_future = smf.ols(formula=model7_linear_form,
                                   data=pokeaman[pokeaman.Generation==1])
model7_gen1_predict_future_fit = model7_gen1_predict_future.fit()
print("'In sample' R-squared:    ", model7_fit.rsquared, "(original)")
y = pokeaman_test.HP
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model7)[0,1]**2, "(original)")
print("'In sample' R-squared:    ", model7_gen1_predict_future_fit.rsquared, "(gen1_predict_future)")
y = pokeaman[pokeaman.Generation!=1].HP
yhat = model7_gen1_predict_future_fit.predict(pokeaman[pokeaman.Generation!=1])
print("'Out of sample' R-squared:", np.corrcoef(y,yhat)[0,1]**2, "(gen1_predict_future)")
# Out:
# 'In sample' R-squared:     0.37818209127432456 (original)
# 'Out of sample' R-squared: 0.35055389205977444 (original)
# 'In sample' R-squared:     0.5726118179916575 (gen1_predict_future)
# 'Out of sample' R-squared: 0.11151363354803218 (gen1_predict_future)

# %% [markdown]
# model7_gen1_predict_future_fit shows how good the knowledge from Gen1 can be used to predict data from other generations, while the original model uses all available data for both training and prediction, all using model7. gen1 is train set, others are all test set. Generalizing seems to get worse than original. Although 'In sample' R-squared is better.

# %%
model7_gen1to5_predict_future = smf.ols(formula=model7_linear_form,
                                   data=pokeaman[pokeaman.Generation!=6])
model7_gen1to5_predict_future_fit = model7_gen1to5_predict_future.fit()
print("'In sample' R-squared:    ", model7_fit.rsquared, "(original)")
y = pokeaman_test.HP
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model7)[0,1]**2, "(original)")
print("'In sample' R-squared:    ", model7_gen1to5_predict_future_fit.rsquared, "(gen1to5_predict_future)")
y = pokeaman[pokeaman.Generation==6].HP
yhat = model7_gen1to5_predict_future_fit.predict(pokeaman[pokeaman.Generation==6])
print("'Out of sample' R-squared:", np.corrcoef(y,yhat)[0,1]**2, "(gen1to5_predict_future)")
# Out:
# 'In sample' R-squared:     0.37818209127432456 (original)
# 'Out of sample' R-squared: 0.35055389205977444 (original)
# 'In sample' R-squared:     0.3904756578094535 (gen1to5_predict_future)
# 'Out of sample' R-squared: 0.23394915464343125 (gen1to5_predict_future)

# %% [markdown]
# Similar to above, but here we use trend conncluded from gen 1 to gen 5 to predict gen 6, so gen1 to gen 5 is train set, gen6 is test set. Generalizing seems to get worse than original. Although 'In sample' R-squared is better.

# %%
model6_gen1_predict_future = smf.ols(formula=model6_linear_form,
                                   data=pokeaman[pokeaman.Generation==1])
model6_gen1_predict_future_fit = model6_gen1_predict_future.fit()
print("'In sample' R-squared:    ", model6_fit.rsquared, "(original)")
y = pokeaman_test.HP
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model6)[0,1]**2, "(original)")
print("'In sample' R-squared:    ", model6_gen1_predict_future_fit.rsquared, "(gen1_predict_future)")
y = pokeaman[pokeaman.Generation!=1].HP
yhat = model6_gen1_predict_future_fit.predict(pokeaman[pokeaman.Generation!=1])
print("'Out of sample' R-squared:", np.corrcoef(y,yhat)[0,1]**2, "(gen1_predict_future)")
# Out:
# 'In sample' R-squared:     0.3326310334310908 (original)
# 'Out of sample' R-squared: 0.29572460427079933 (original)
# 'In sample' R-squared:     0.4433880517727282 (gen1_predict_future)
# 'Out of sample' R-squared: 0.1932858534276128 (gen1_predict_future)

# %% [markdown]
# Similar to model7_gen1_predict_future, but we use model 6 instead. Generalizing seems to get worse than original. Although 'In sample' R-squared is better. But better than model7.

# %%
model6_gen1to5_predict_future = smf.ols(formula=model6_linear_form,
                                   data=pokeaman[pokeaman.Generation!=6])
model6_gen1to5_predict_future_fit = model6_gen1to5_predict_future.fit()
print("'In sample' R-squared:    ", model6_fit.rsquared, "(original)")
y = pokeaman_test.HP
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model6)[0,1]**2, "(original)")
print("'In sample' R-squared:    ", model6_gen1to5_predict_future_fit.rsquared, "(gen1to5_predict_future)")
y = pokeaman[pokeaman.Generation==6].HP
yhat = model6_gen1to5_predict_future_fit.predict(pokeaman[pokeaman.Generation==6])
print("'Out of sample' R-squared:", np.corrcoef(y,yhat)[0,1]**2, "(gen1to5_predict_future)")
# Out:
# 'In sample' R-squared:     0.3326310334310908 (original)
# 'Out of sample' R-squared: 0.29572460427079933 (original)
# 'In sample' R-squared:     0.33517279824114776 (gen1to5_predict_future)
# 'Out of sample' R-squared: 0.26262690178799936 (gen1to5_predict_future)

# %% [markdown]
# Similar to model7_gen1to5_predict_future, but we use model 6 instead. Generalizing seems to get worse than original by a little. Although 'In sample' R-squared is better. But better than model7.
